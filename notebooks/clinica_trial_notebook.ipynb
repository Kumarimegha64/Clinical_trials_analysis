# %%
# !pip install pandas sqlalchemy psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:123456@localhost:5432/DATABASE_NAME"
)

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:123456@localhost:5432/clinical_trials"
)

# %%
df = pd.read_sql(
    "SELECT * FROM clean_trials",
    engine
)

# %%
df.shape
# Out:
# (8089, 27)

# %%
df.head(10)
# Out:
#    rank   nct_number                                              title  \
# 0   615  NCT04409184  Whole Blood Collection From Individuals in the...
# 1   561  NCT04422626  Data Analysis of the Cytokine Adsorption Treat...
# 2   562  NCT05007275  A Study to Determine Safety and Immunogenicity...
# 3   563  NCT04371640                      Sirolimus in COVID-19 Phase 1
# 4   565  NCT04993560  Safety and Efficacy of COVID-19 Prime-boost Va...
# 5   566  NCT05148962  Study of GRT-R910 COVID-19 Boost Vaccine in He...
# 6   567  NCT04355338  Assessment of Incidence of SARS-CoV-2 Infectio...
# 7   844  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# 8   266  NCT04893070  Impact of SARS-CoV-2 (COVID-19) Infection, Tre...
# 9   616  NCT05313074  SARS-CoV-2 Specific Immune Response After COVI...
#
#          acronym              status         study_results  \
# 0           None           Withdrawn  No Results Available
# ...

# %%
df.isnull().sum()
# Out:
# rank                                0
# nct_number                          0
# title                               0
# acronym                          4797
# status                              0
# study_results                       0
# conditions                          0
# interventions                    1223
# outcome_measures                    0
# sponsor_collaborators               0
# gender                              0
# age                                 0
# phases                           3506
# enrollment                          0
# funded_bys                          0
# study_type                          0
# study_designs                       0
# other_ids                           0
# locations                         653
# url                                 0
# start_date_clean                    0
# primary_completion_date_clean       0
# completion_date_clean               0
# first_posted_clean                  0
# last_update_posted_clean            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8089 entries, 0 to 8088
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rank                           8089 non-null   int64
#  1   nct_number                     8089 non-null   object
#  2   title                          8089 non-null   object
#  3   acronym                        3292 non-null   object
#  4   status                         8089 non-null   object
#  5   study_results                  8089 non-null   object
#  6   conditions                     8089 non-null   object
#  7   interventions                  6866 non-null   object
#  8   outcome_measures               8089 non-null   object
#  9   sponsor_collaborators          8089 non-null   object
#  10  gender                         8089 non-null   object
#  11  age                            8089 non-null   object
# ...

# %%
df['age_category'].isnull().sum()
# Out:
# 0

# %%
df['age_category'] = df['age_category'].fillna(df['age'])

# %%
df['age_category'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# rank                                0
# nct_number                          0
# title                               0
# acronym                          4797
# status                              0
# study_results                       0
# conditions                          0
# interventions                    1223
# outcome_measures                    0
# sponsor_collaborators               0
# gender                              0
# age                                 0
# phases                           3506
# enrollment                          0
# funded_bys                          0
# study_type                          0
# study_designs                       0
# other_ids                           0
# locations                         653
# url                                 0
# start_date_clean                    0
# primary_completion_date_clean       0
# completion_date_clean               0
# first_posted_clean                  0
# last_update_posted_clean            0
# ...

# %%
df['country'] = df['country'].fillna("Others")

# %%
df['country'].value_counts()
# Out:
# country
# United States     1551
# France             843
# Others             653
# Turkey             405
# United Kingdom     386
#                   ...
# Albania              1
# Sierra Leone         1
# South Sudan          1
# Cambodia             1
# Cameroon             1
# Name: count, Length: 133, dtype: int64

# %%
df=df.dropna(subset=["study_designs"])
df=df.dropna(subset=["other_ids"])
df=df.dropna(subset=["primary_completion_date_clean"])
df=df.dropna(subset=["completion_date_clean"])

# %%
df.isnull().sum()
# Out:
# rank                                0
# nct_number                          0
# title                               0
# acronym                          4797
# status                              0
# study_results                       0
# conditions                          0
# interventions                    1223
# outcome_measures                    0
# sponsor_collaborators               0
# gender                              0
# age                                 0
# phases                           3506
# enrollment                          0
# funded_bys                          0
# study_type                          0
# study_designs                       0
# other_ids                           0
# locations                         653
# url                                 0
# start_date_clean                    0
# primary_completion_date_clean       0
# completion_date_clean               0
# first_posted_clean                  0
# last_update_posted_clean            0
# ...

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (8089, 27)
# ['rank', 'nct_number', 'title', 'acronym', 'status', 'study_results', 'conditions', 'interventions', 'outcome_measures', 'sponsor_collaborators', 'gender', 'age', 'phases', 'enrollment', 'funded_bys', 'study_type', 'study_designs', 'other_ids', 'locations', 'url', 'start_date_clean', 'primary_completion_date_clean', 'completion_date_clean', 'first_posted_clean', 'last_update_posted_clean', 'country', 'age_category']

# %%
df.to_sql(
    "clean_trials",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 89

# %%
check = pd.read_sql(
    "SELECT * FROM clean_trials",
    engine
)
print(check.shape)
# Out:
# (8089, 27)

# %%
print("Jupyter:", df.shape)
print("PostgreSQL:", check.shape)
# Out:
# Jupyter: (8089, 27)
# PostgreSQL: (8089, 27)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Acer

# %%
import os

os.chdir(r"C:\Users\Acer\Desktop\Megha Project\clinical data quality")

print(os.getcwd())
# Out:
# C:\Users\Acer\Desktop\Megha Project\clinical data quality

# %%
print(os.listdir())
# Out:
# ['.dockerignore', '.gitignore', '.pytest_cache', 'api', 'app', 'charts', 'data', 'docker-compose.yml', 'Dockerfile', 'notebooks', 'python', 'README.md', 'reports', 'requirements.txt', 'scripts', 'sql', 'test', 'tests', 'venv']

# %%
from pathlib import Path

Path("data/processed").mkdir(parents=True, exist_ok=True)

# %%
df = df.rename(columns={
    "nct_number": "nct_id",
    "phases": "phase",
    "start_date_clean": "start_date",
    "completion_date_clean": "completion_date"
})

# %%
df.to_csv(
    "data/processed/clean_trials_data.csv",
    index=False
)

# %%
print(df.columns.tolist())
# Out:
# ['rank', 'nct_id', 'title', 'acronym', 'status', 'study_results', 'conditions', 'interventions', 'outcome_measures', 'sponsor_collaborators', 'gender', 'age', 'phase', 'enrollment', 'funded_bys', 'study_type', 'study_designs', 'other_ids', 'locations', 'url', 'start_date', 'primary_completion_date_clean', 'completion_date', 'first_posted_clean', 'last_update_posted_clean', 'country', 'age_category']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Acer\Desktop\Megha Project\clinical data quality

# %%
from pathlib import Path

csv_path = Path("data/processed/clean_trials_data.csv")

print(csv_path.resolve())
print(csv_path.exists())
# Out:
# C:\Users\Acer\Desktop\Megha Project\clinical data quality\data\processed\clean_trials_data.csv
# True

# %%
from pathlib import Path

print(list(Path("notebooks").glob("*.ipynb")))
# Out:
# [WindowsPath('notebooks/clinical_trial_notebook.ipynb')]
